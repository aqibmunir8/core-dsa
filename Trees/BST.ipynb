# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.left = None
        self.right = None


def insert(root, value):
    if (root == None):
        return Node(value)
    if (root.data == value):
        return root
    if (root.data > value):
        root.left = insert(root.left, value)
    else: 
        root.right = insert(root.right, value)
    return root


def search(root, value):
    if (root == None):
        print("Element Not Found!")
        return
    if (root.data == value):
        print("Element Found !")
        return 
    if (root.data > value):
        search(root.left, value)
    else: 
        search(root.right, value)

def inorder(root):
    if root:
        inorder(root.left)
        print(root.data, end=' ')
        inorder(root.right)

def get_successor(root):
    root = root.right
    while(root != None and root.left != None):
        root = root.left
    return root

def delete(root, value):
    
    if (root == None):
        return root
    if (root.data > value):
        root.left = delete(root.left, value)
    elif (root.data < value):
        root.right = delete(root.right, value)

    else:
        if(root.left == None):
            return root.right
        if(root.right == None):
            return root.left
    return root
    



root = insert(None, 10)
root = insert(root, 20)
root = insert(root, 80)
root = insert(root, 90)
root = insert(root, 2)
root = insert(root, -9)

inorder(root)

search(root, 20)
search(root, 100)
delete(root, 80)
inorder(root)
# Out:
# -9 2 10 20 80 Element Found !
# Element Not Found!
# 20
# 10
# -9 2 10 20

# %%
class Node:
    def __init__(self, value):
        self.data = value
        self.left = None
        self.right = None

# Write BST class with insert and search methods and print inOrder traversal of the tree
class BST:
    def __init__(self):
        self.root = None

    def insert(self, value):
        if self.root is None:
            self.root = Node(value)
        else:
            self._insert_recursively(self.root, value)

    def _insert_recursively(self, node, value):
        if value < node.data:
            if node.left is None:
                node.left = Node(value)
            else:
                self._insert_recursively(node.left, value)
        else:
            if node.right is None:
                node.right = Node(value)
            else:
                self._insert_recursively(node.right, value)

    def search(self, value):
        return self._search_recursively(self.root, value)

    def _search_recursively(self, node, value):
        if node is None:
            return False
        if node.data == value:
            return True
        elif value < node.data:
            return self._search_recursively(node.left, value)
        else:
            return self._search_recursively(node.right, value)

    def __str__(self):
        return str(self._in_order(self.root))

    def _in_order(self, node):
        elements = []
        if node:
            elements += self._in_order(node.left)
            elements.append(node.data)
            elements += self._in_order(node.right)
        return elements
    

# Create a BST and insert some values
bst = BST()
values_to_insert = [5, 3, 7, 2, 4, 6, 8]
for value in values_to_insert:
    bst.insert(value)

print("InOrder Traversal of the BST: ", bst)
